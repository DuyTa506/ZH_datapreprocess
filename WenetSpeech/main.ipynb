# %% [markdown]
# # get in4 x sample from wenetspeech.json

# %%
import json
import ijson
from decimal import Decimal

def decimal_default(obj):
    if isinstance(obj, Decimal):
        return float(obj)
    raise TypeError

def read_and_save_to_json(file_path, output_json_path, num_records=10):
    try:
        # Mở và đọc nội dung từ tệp JSON
        with open(file_path, 'r', encoding='utf-8') as file:
            # Sử dụng mô-đun ijson để xử lý từng bản ghi một
            objects = ijson.items(file, 'audios.item')

            # Ghi thông tin vào file .json
            with open(output_json_path, 'w', encoding='utf-8') as output_file:
                # Đọc từng bản ghi và ghi vào file .json
                data_to_write = []
                for i in range(num_records):
                    try:
                        record = next(objects)
                        data_to_write.append(record)
                    except StopIteration:
                        print("Đã đọc hết các bản ghi.")
                        break

                # Sử dụng default để chuyển đổi Decimal thành float
                json.dump(data_to_write, output_file, indent=2, default=decimal_default, ensure_ascii=False)
    except Exception as e:
        print(f"Có lỗi xảy ra: {e}")

# Thay đổi đường dẫn đến tệp JSON và tên file .json đích của bạn
json_file_path = '/app/WenetSpeech/WenetSpeech/WenetSpeech.json'
output_json_path = '/app/ZH_datapreprocess/WenetSpeech/example.json'
read_and_save_to_json(json_file_path, output_json_path, num_records=1000)

# %%
import json
import ijson
from decimal import Decimal

def decimal_default(obj):
    if isinstance(obj, Decimal):
        return float(obj)
    raise TypeError

def read_and_save_to_json(file_path, output_json_path, start_record=0, num_records=10):
    try:
        # Mở và đọc nội dung từ tệp JSON
        with open(file_path, 'r', encoding='utf-8') as file:
            # Sử dụng mô-đun ijson để xử lý từng bản ghi một
            objects = ijson.items(file, 'audios.item')

            # Chỉ đọc num_records bản ghi từ start_record
            for _ in range(start_record):
                next(objects, None)

            # Ghi thông tin vào file .json
            with open(output_json_path, 'w', encoding='utf-8') as output_file:
                # Đọc và ghi num_records bản ghi
                data_to_write = []
                for _ in range(num_records):
                    try:
                        record = next(objects)
                        if record is not None:
                            data_to_write.append(record)
                    except StopIteration:
                        print("Đã đọc hết các bản ghi.")
                        break

                # Sử dụng default để chuyển đổi Decimal thành float
                json.dump(data_to_write, output_file, indent=2, default=decimal_default, ensure_ascii=False)
    except Exception as e:
        print(f"Có lỗi xảy ra: {e}")

# Thay đổi đường dẫn đến tệp JSON và tên file .json đích của bạn
json_file_path = '/app/WenetSpeech/WenetSpeech/WenetSpeech.json'

# Ghi 1000 bản ghi vào file json1.json từ bản ghi thứ 0
read_and_save_to_json(json_file_path, '/app/ZH_datapreprocess/WenetSpeech/json1.json', start_record=0, num_records=2000)

# Ghi 1000 bản ghi tiếp theo vào file json2.json từ bản ghi thứ 1000
#read_and_save_to_json(json_file_path, '/app/ZH_datapreprocess/WenetSpeech/json2.json', start_record=1000, num_records=1000)

# %% [markdown]
# # view in4 all key in json file

# %%
import json

def display_json_fields(file_path):
    try:
        # Mở và đọc nội dung từ tệp JSON
        with open(file_path, 'r', encoding='utf-8') as file:
            data = json.load(file)

            # Hiển thị thông tin về các trường trong JSON
            if isinstance(data, list):
                # Nếu JSON chứa danh sách các đối tượng
                for record in data:
                    print(f"Fields in a record:")
                    for key in record.keys():
                        print(f"- {key}")
                    print("\n" + "-" * 40 + "\n")
            elif isinstance(data, dict):
                # Nếu JSON chứa một đối tượng
                print(f"Fields in the object:")
                for key in data.keys():
                    print(f"- {key}")
            else:
                print("Invalid JSON format.")
    except Exception as e:
        print(f"Có lỗi xảy ra: {e}")

# Thay đổi đường dẫn đến tệp JSON của bạn
json_file_path = '/app/ZH_datapreprocess/WenetSpeech/example.json'
display_json_fields(json_file_path)
# Out:
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ...
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------
#
# Fields in a record:
# - aid
# - duration
# - md5
# - path
# - source
# - tags
# - url
# - segments
#
# ----------------------------------------

# %%
import os

def count_files_in_directory(directory):
    try:
        # Sử dụng list comprehension để lọc ra các tệp là file trong thư mục
        files = [f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))]
        
        # Đếm số lượng file
        count = len(files)
        
        return count
    except Exception as e:
        print(f"Có lỗi xảy ra: {e}")
        return None

# Thay đổi đường dẫn đến thư mục của bạn
directory_path = '/app/WenetSpeech/Cleaned_data'
file_count = count_files_in_directory(directory_path)

if file_count is not None:
    print(f"Số lượng file trong thư mục {directory_path}: {file_count}")
else:
    print("Không thể đếm số lượng file.")
# Out:
# Số lượng file trong thư mục /app/WenetSpeech/Cleaned_data: 289000

# %% [markdown]
# # change type audio file

# %%
import subprocess
import os

def convert_opus_to_wav(input_path, output_path):
    try:
        # Sử dụng FFmpeg để chuyển đổi từ Opus sang WAV
        subprocess.run(['ffmpeg', '-i', input_path, output_path], check=True)
        print(f"Đã chuyển đổi file {input_path} thành {output_path}")
    except subprocess.CalledProcessError as e:
        print(f"Có lỗi xảy ra: {e}")

# Thay đổi đường dẫn đến file Opus của bạn và đặt đường dẫn đến file WAV đầu ra
input_opus_path = '/app/ZH_datapreprocess/WenetSpeech/Cleaned_data/20.08_24.4.opus'
output_wav_path = '/app/ZH_datapreprocess/WenetSpeech/Cleaned_data/20.08_24.4.wav'

# Lấy tên file (không bao gồm đuôi mở rộng)
file_name = os.path.splitext(os.path.basename(input_opus_path))[0]
# Gắn đuôi mở rộng WAV vào tên file
output_wav_path = os.path.join(os.path.dirname(output_wav_path), f"{file_name}.wav")

# Chuyển đổi file Opus thành WAV
convert_opus_to_wav(input_opus_path, output_wav_path)
# Out:
# Đã chuyển đổi file /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/20.08_24.4.opus thành /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/20.08_24.4.wav
# ffmpeg version 5.1.4-0+deb12u1 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12 (Debian 12.2.0-14)
#   configuration: --prefix=/usr --extra-version=0+deb12u1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librist --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --disable-sndio --enable-libjxl --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-libplacebo --enable-librav1e --enable-shared
#   libavutil      57. 28.100 / 57. 28.100
#   libavcodec     59. 37.100 / 59. 37.100
#   libavformat    59. 27.100 / 59. 27.100
#   libavdevice    59.  7.100 / 59.  7.100
#   libavfilter     8. 44.100 /  8. 44.100
#   libswscale      6.  7.100 /  6.  7.100
#   libswresample   4.  7.100 /  4.  7.100
#   libpostproc    56.  6.100 / 56.  6.100
# Input #0, ogg, from '/app/ZH_datapreprocess/WenetSpeech/Cleaned_data/20.08_24.4.opus':
#   Duration: 00:00:04.34, start: 0.020000, bitrate: 33 kb/s
#   Stream #0:0: Audio: opus, 48000 Hz, mono, fltp
#     Metadata:
#       encoder         : Lavc57.107.100 libopus
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/app/ZH_datapreprocess/WenetSpeech/Cleaned_data/20.08_24.4.wav':
#   Metadata:
#     ISFT            : Lavf59.27.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, mono, s16, 768 kb/s
#     Metadata:
#       encoder         : Lavc59.37.100 pcm_s16le
# size=     405kB time=00:00:04.31 bitrate= 768.1kbits/s speed= 513x
# video:0kB audio:405kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.018817%

# %% [markdown]
# # get in4 some key in sub json file

# %%
import json
from pydub import AudioSegment
import os 
import subprocess
# root_path = os.getcwd()
output_path = "/app/ZH_datapreprocess/WenetSpeech/Cleaned_data"
os.makedirs(output_path, exist_ok=True)

def find_opus_files(folder_path):
    opus_files = []

    # Duyệt qua tất cả các thư mục và tệp tin trong thư mục chính
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            # Kiểm tra nếu tệp có đuôi là ".opus"
            if file.endswith(".opus"):
                # Tạo đường dẫn đầy đủ và thêm vào danh sách
                file_path = os.path.join(root, file)
                opus_files.append(file_path)
    return opus_files

def cut_opus_file(input_path, output_path, start_time, end_time):
    try:
        # Đọc file âm thanh Opus
        audio = AudioSegment.from_file(input_path, format="opus")

        # Chuyển đổi thời gian từ giây sang miligiây
        start_time_ms = start_time * 1000
        end_time_ms = end_time * 1000

        # Cắt file âm thanh
        cut_audio = audio[start_time_ms:end_time_ms]

        # Lưu file âm thanh đã cắt
        cut_audio.export(output_path, format="opus")

        print(f"Đã cắt file từ {start_time} giây đến {end_time} giây và lưu thành {output_path}")
    except Exception as e:
        print(f"Có lỗi xảy ra: {e}")
        
def cut_opus_file_ffmpeg(input_path, output_path, start_time, end_time):
    try:
        # Sử dụng FFmpeg để cắt file âm thanh
        subprocess.run([
            'ffmpeg',
            '-i', input_path,
            '-ss', str(start_time),
            '-to', str(end_time),
            '-c', 'copy',
            output_path
        ], check=True)

        print(f"Đã cắt file từ {start_time} giây đến {end_time} giây và lưu thành {output_path}")
    except subprocess.CalledProcessError as e:
        print(f"Có lỗi xảy ra: {e}")

# Thay đổi đường dẫn đến file Opus của bạn và đặt thời gian cắt
# input_opus_path = '/path/to/your/input.opus'
# output_opus_path = '/path/to/your/output.opus'
# start_time_to_cut = 10  # Thời điểm bắt đầu cắt (giây)
# end_time_to_cut = 20    # Thời điểm kết thúc cắt (giây)

# cut_opus_file(input_opus_path, output_opus_path, start_time_to_cut, end_time_to_cut)
def find_element_containing_a(a, str_list):
    for element in str_list:
        if a in element:
            return element
    return None


def get_duration_from_json(json_path):
    try:
        main_folder = '/app/WenetSpeech/WenetSpeech/audio'
# Lấy tất cả đường dẫn của các tệp .opus trong thư mục con
        opus_file_paths = find_opus_files(main_folder)
        # Mở và đọc nội dung từ tệp JSON
        with open(json_path, 'r', encoding='utf-8') as file:
            # Load dữ liệu JSON
            data = json.load(file)

            # Lặp qua từng bản ghi và lấy thông tin của trường "duration"
            for i,record in enumerate(data):
                print(f"-----------------dang xu ly ban ghi thu {i}")         
                path = record.get("path")
                segments = record.get("segments")
                full_path = find_element_containing_a(path, opus_file_paths)
                for x in segments: 
                    begin_time = x.get('begin_time')
                    end_time = x.get('end_time')
                    output_opus_path = f'{output_path}/{begin_time}_{end_time}.opus'
                    output_txt_path = f'{output_path}/{begin_time}_{end_time}.txt'
                    print(output_opus_path)
                    text = x.get('text')
                    cut_opus_file_ffmpeg(full_path, output_opus_path, begin_time, end_time)
                    with open(output_txt_path, 'w', encoding='utf-8') as f:
                        f.write(text)
                
    except Exception as e:
        print(f"Có lỗi xảy ra: {e}")

# Thay đổi đường dẫn đến tệp JSON của bạn
example_json_path = '/app/ZH_datapreprocess/WenetSpeech/json1.json'
get_duration_from_json(example_json_path)

# %%
import json
import os
import subprocess
import concurrent.futures
from concurrent.futures import ThreadPoolExecutor

output_path = "/app/ZH_datapreprocess/WenetSpeech/Cleaned_data"
os.makedirs(output_path, exist_ok=True)

def find_opus_files(folder_path):
    opus_files = []
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith(".opus"):
                file_path = os.path.join(root, file)
                opus_files.append(file_path)
    return opus_files

def cut_opus_file_ffmpeg(input_path, output_path, start_time, end_time):
    try:
        subprocess.run([
            'ffmpeg',
            '-i', input_path,
            '-ss', str(start_time),
            '-to', str(end_time),
            '-c', 'copy',
            output_path
        ], check=True)

        print(f"Đã cắt file từ {start_time} giây đến {end_time} giây và lưu thành {output_path}")
    except subprocess.CalledProcessError as e:
        print(f"Có lỗi xảy ra: {e}")

def find_element_containing_a(a, str_list):
    for element in str_list:
        if a in element:
            return element
    return None

def process_record(record, opus_file_paths):
    path = record.get("path")
    segments = record.get("segments")
    full_path = find_element_containing_a(path, opus_file_paths)
    for x in segments:
        begin_time = x.get('begin_time')
        end_time = x.get('end_time')
        output_opus_path = f'{output_path}/{begin_time}_{end_time}.opus'
        output_txt_path = f'{output_path}/{begin_time}_{end_time}.txt'
        print(output_opus_path)
        text = x.get('text')
        cut_opus_file_ffmpeg(full_path, output_opus_path, begin_time, end_time)
        with open(output_txt_path, 'w', encoding='utf-8') as f:
            f.write(text)

def get_duration_from_json(json_path):
    try:
        main_folder = '/app/WenetSpeech/WenetSpeech/audio'
        opus_file_paths = find_opus_files(main_folder)

        with open(json_path, 'r', encoding='utf-8') as file:
            data = json.load(file)

            with ThreadPoolExecutor() as executor:
                future_to_record = {executor.submit(process_record, record, opus_file_paths): record for record in data}
                
                for future in concurrent.futures.as_completed(future_to_record):
                    record = future_to_record[future]
                    try:
                        future.result()
                    except Exception as e:
                        print(f"Xảy ra lỗi khi xử lý bản ghi: {e}")

    except Exception as e:
        print(f"Có lỗi xảy ra: {e}")

# Thay đổi đường dẫn đến tệp JSON của bạn
example_json_path = '/app/ZH_datapreprocess/WenetSpeech/json2.json'
get_duration_from_json(example_json_path)

# %%
import os

def delete_files_in_directory(directory_path):
    try:
        # Lặp qua tất cả các tệp trong thư mục
        for file_name in os.listdir(directory_path):
            file_path = os.path.join(directory_path, file_name)
            
            # Kiểm tra xem đối tượng có phải là tệp không
            if os.path.isfile(file_path):
                # Xóa tệp
                os.remove(file_path)
                print(f"Đã xóa tệp: {file_path}")

        print("Đã xóa tất cả các tệp trong thư mục thành công.")
    except Exception as e:
        print(f"Có lỗi xảy ra: {e}")

# Thay đổi đường dẫn đến thư mục của bạn
directory_to_clear = '/app/ZH_datapreprocess/WenetSpeech/Cleaned_data'

# Gọi hàm để xóa tất cả các tệp trong thư mục
delete_files_in_directory(directory_to_clear)
# Out:
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/240.2_241.52_RQprM.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/672.12_673.4_FFohV.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/264.03_270.61_jWbEW.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/645.52_646.44_cQolZ.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/901.83_908.21_qfZTo.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/679.12_680.6_a8IMJ.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/729.48_730.56_LzUP0.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/160.91_168.29_9QA5h.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/925.71_932.81_QDd2c.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/147.28_152.64_m1icd.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/168.93_170.45_sEX6O.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1112.95_1119.25_ZR1UG.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/728.39_734.81_LUDup.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/796.98_801.3_2BWLo.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/835.48_837.32_EjpKQ.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/243.55_249.61_n6Jgi.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/280.52_281.64_vYosI.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/191.02_194.34_nHN9f.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/785.9_789.62_cT4Sq.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/242.88_247.4_4WFtO.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/294.2_299.28_qk12Y.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/386.68_388.45_wKOxX.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/920.72_922.8_QbCgi.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/429.24_431.04_v1JT2.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/305.28_307.28_8dvG0.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/40.79_45.09_4BpPa.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/286.76_293.32_SjVnj.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/865.51_872.73_yfIak.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/915.92_921.4_w4Jg0.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/653.79_660.33_5JP9L.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/377.84_379.91_XDkJW.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/569.68_577.32_c1yVj.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/190.8_192.6_VFMUQ.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/515.13_516.7_ZL8YH.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/315.15_322.45_1dAVa.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/397.72_405.16_ukXBQ.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/718.2_719.2_wkhVt.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/521.52_524.04_dd9fw.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/876.16_877.52_yIiTH.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/262.0_264.28_11l04.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/328.76_330.2_m6Pzc.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/953.51_960.29_tuck9.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/164.87_171.77_n3OFi.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/412.36_418.8_3umGf.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1211.15_1219.09_isGYn.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/740.96_742.84_hERNH.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1031.88_1033.88_HuIKr.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/610.6_612.6_GIHkh.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/511.76_516.0_1fw7n.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/230.96_233.24_pxcnh.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/943.62_947.02_sZn9l.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1000.44_1002.52_oToS2.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/356.04_359.32_xCVDK.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/560.88_562.24_i281d.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/594.75_601.85_eSFhP.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/287.64_290.88_pqncu.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/737.88_741.96_2JeA4.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/148.43_149.82_uTXN9.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/980.87_987.77_VWeT7.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/203.2_207.0_GDuOl.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1258.88_1260.32_GnBzF.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/247.6_249.4_KgVPK.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/36.68_41.2_yGZT9.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/708.38_710.2_G0D2C.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/496.44_499.12_AQEy3.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/659.68_660.84_X3I6G.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/709.0_711.2_bs3Di.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/647.92_648.92_Fi1Ws.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/660.84_662.88_amJKT.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1093.76_1095.84_f2mO1.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/685.2_691.88_fmyH3.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/532.2_533.24_ueY5Z.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/603.97_606.41_tdFUb.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/933.04_940.04_isgoz.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/315.15_322.45_1dAVa.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/379.12_381.36_O1sGe.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/170.44_173.0_EENL2.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/607.59_609.03_pgUKS.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/565.67_568.16_pHSnD.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/656.58_659.66_DXP3Q.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/459.52_467.28_Xy8DL.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/689.4_690.76_eW273.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/276.04_280.92_DJpwF.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1315.16_1317.92_dX15G.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/122.84_130.64_SorOu.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/620.92_623.08_hyRdP.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/266.56_269.68_P6rEk.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/600.2_602.12_zNjAS.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/681.56_683.08_F2GXJ.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/69.8_77.8_Ug0wE.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/951.26_955.54_fzm5p.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1067.2_1069.48_4M0bx.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/432.6_434.4_jtfpM.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1043.55_1050.49_BP3pS.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/222.36_230.48_z9xOP.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/317.92_319.2_Ykv4X.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/683.47_691.33_sWELa.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/951.52_956.84_vmw4t.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/837.32_839.2_Ht9Ew.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1063.59_1070.61_4GlDc.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/776.09_780.87_y6dH9.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/503.2_506.12_70eNp.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/837.84_838.83_RLzK7.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/627.04_629.28_2zBmg.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1246.67_1252.33_6mICn.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/503.2_506.12_70eNp.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/685.04_686.36_Fkxoc.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1239.59_1241.85_A6DqA.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/358.87_363.97_1tbYv.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/573.28_574.16_SyIeK.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1214.24_1220.48_2CUCZ.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/419.72_426.8_9YFFH.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/305.28_307.28_8dvG0.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/499.83_506.01_BRDA1.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/356.28_363.28_RIbtZ.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/546.14_550.02_g9foz.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/670.04_672.6_Vpqam.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/431.12_432.6_Z81V5.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/130.32_137.04_rQgMD.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/316.97_318.53_4XTDL.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/948.95_956.53_qKoRX.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/341.59_343.2_rjEIz.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/837.84_838.83_RLzK7.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/205.02_210.7_D2HPt.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/693.76_700.32_agylV.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/689.84_691.12_EE9bY.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/378.95_386.53_nC24g.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1351.32_1353.24_9TsL9.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/558.36_560.52_yu8aG.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/601.64_607.96_NzmEG.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/510.2_511.56_WOk2r.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1344.04_1349.48_PdgpL.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/902.32_908.72_PjSum.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1179.67_1182.25_0UhR1.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/473.76_474.68_4twsO.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1478.04_1480.52_9bFqb.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1018.96_1020.96_XgZU0.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/284.36_285.8_tVXEi.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/555.4_562.84_eAjTf.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/933.88_939.56_6M2yY.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/775.7_778.74_YCyF0.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/602.32_606.08_IWMz9.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/592.4_594.0_O9V9y.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/256.2_257.64_NHVn9.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/122.94_127.86_hubbj.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/349.44_356.64_jSPuK.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/417.32_419.44_30QQD.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/349.75_352.29_I5FXK.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/624.92_628.96_dxt1c.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/715.12_722.88_LsvVD.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/276.4_280.2_drbmQ.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/727.8_728.76_Wyctv.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/856.88_858.84_NhW2V.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/562.24_563.36_NQNO0.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/393.72_397.48_TfUTT.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1289.08_1296.24_KsOTq.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/930.96_933.72_UoHgx.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1214.6_1219.64_NvkzB.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/391.28_398.08_d2SH2.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/468.34_471.5_HucB6.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1189.79_1193.25_jtWfl.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/707.4_709.72_LJyTT.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/348.42_353.42_SMXab.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/681.4_683.52_dWs6i.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/457.96_460.12_T6XkK.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/804.92_806.56_20H1w.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/811.72_815.04_kZvw6.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/277.92_280.44_A5VSc.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/601.87_607.65_9mSDB.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/998.47_1003.97_JUj2s.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/493.2_500.4_NBZ6Y.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/469.2_472.56_UxxvC.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1106.52_1109.36_rpSDD.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/831.72_833.44_DRVDD.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/463.32_464.88_zOPWh.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/543.08_544.56_d5QHK.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/56.48_61.24_7QZtP.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/133.36_137.96_VbsJr.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/618.76_621.52_2ePja.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/520.43_523.01_rx82d.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/807.55_809.2_dL3Cv.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/717.04_719.88_F7sgT.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/152.16_155.12_oXqnH.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/285.8_288.04_syK71.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1118.63_1126.01_WhFEg.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1481.52_1483.68_3bBkH.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/569.0_570.08_SKn2r.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/455.44_458.16_C6oCR.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/666.32_667.48_wagzD.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/370.56_371.4_KanxC.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/576.26_579.38_BF4Ob.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/236.84_239.32_zMxuJ.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/82.04_85.12_ZWLRD.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1124.16_1125.48_CNXug.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/472.04_475.24_20E9G.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/810.8_814.12_s4HE3.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/534.64_536.76_KCyxt.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/765.23_771.97_PoYTy.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1351.32_1353.24_9TsL9.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/259.0_261.96_Z3piX.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1010.32_1011.72_txnwy.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/780.59_788.83_r4aBD.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/574.0_576.2_IXuKj.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/54.31_60.29_mjgqW.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/286.76_293.32_SjVnj.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/377.6_385.96_t1NAi.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/352.84_354.12_eZVo3.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/742.76_744.72_Heb3D.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/151.8_153.92_TeTlv.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/760.91_768.29_tRhNY.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/223.44_225.12_pjeH1.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/215.56_218.36_sscNS.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/961.64_969.72_TFeLh.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1104.82_1110.34_yY5or.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/823.52_824.88_wWKlj.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/586.92_587.83_wNDil.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/451.64_459.88_JI5qL.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1008.76_1009.96_Osg5s.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/110.18_115.34_EUwjq.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/736.08_737.8_Txue8.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/319.64_321.36_e8GIm.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/466.88_468.2_FR4Hn.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/585.72_586.8_bPvLP.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/643.44_644.84_CXKke.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1049.24_1051.8_pFXd2.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/655.36_657.48_EUajy.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/639.87_646.13_OJfdS.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/136.23_144.17_lpHAo.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/26.68_30.48_CvJRc.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/830.14_836.62_8yxuX.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/272.08_274.12_6wGq6.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/154.96_162.72_fourH.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/944.6_948.4_j1PWu.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/763.47_764.53_ClBJh.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/197.55_199.49_pDY7L.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/419.08_421.0_uRTeb.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/479.76_486.32_Z8ltL.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1090.4_1094.44_LVm4K.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/211.6_214.6_mqfHm.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/425.72_427.49_HX3AG.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1001.54_1008.9_jAyt8.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/577.72_578.8_0YjsB.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/669.55_674.45_2MeIO.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/589.96_591.72_OXysY.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/336.48_343.04_oKUWx.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/520.42_522.49_cPNNa.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/477.23_485.09_U5ucH.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/627.2_628.36_cYbs3.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/208.56_209.8_U5DOO.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/366.3_368.78_VOOPC.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/715.4_717.4_YFjdX.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/820.47_821.78_uASuu.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/782.08_788.12_vyPwO.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/202.54_203.9_TA00f.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/199.3_201.16_d1Xbl.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/728.51_733.49_LZ7D5.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/707.4_715.16_DvmIp.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/455.44_458.16_C6oCR.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/816.98_820.26_Y63op.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/514.76_522.52_tCvJq.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/837.24_840.72_XrVbX.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/728.8_730.48_oTykV.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/293.2_296.64_8XNwi.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/632.8_634.2_u2KMv.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1102.64_1110.68_GAaOm.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/749.91_757.61_imu5C.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/968.9_975.98_kDF2f.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/695.71_700.37_PX1gW.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/112.42_113.66_T1UdZ.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/802.48_803.56_uoID3.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/336.48_343.04_oKUWx.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/313.32_314.4_juz6Z.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/805.66_807.46_FZyh8.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/765.23_771.97_PoYTy.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/492.99_499.33_0tOJW.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/677.96_680.28_BKBez.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/831.91_839.29_vLY3r.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/578.12_579.92_CqTD6.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/532.36_533.96_WvuDW.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/923.16_924.68_1dEyV.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1133.63_1140.85_OVdyg.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/215.12_217.84_CdvAT.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/136.44_138.84_iomsY.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/452.76_455.36_AQV7f.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/675.84_678.0_q9nGG.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1276.83_1283.93_lj1mo.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/612.4_615.36_5Qykt.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/311.96_315.72_dsn37.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/342.92_346.2_8CRKe.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/130.32_137.04_rQgMD.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/353.96_355.68_DgyPD.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/539.83_546.13_KG8qP.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/301.08_303.96_Ofial.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/676.16_680.28_e5XzG.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/573.28_574.16_SyIeK.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/563.2_566.68_HZjOu.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/203.63_209.93_efPQ8.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1379.92_1381.04_fKBzY.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/107.72_112.92_fyJAm.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/766.68_770.04_vtVGr.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/507.6_510.12_BE4g2.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/526.16_527.28_woAim.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1110.9_1112.78_1CIN9.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/386.28_390.16_QiUJU.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/552.84_555.76_q1ah4.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1002.88_1005.36_Tf10V.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/968.55_975.45_Ybgmo.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1199.35_1206.77_sRBQO.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/121.88_123.52_yul73.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1182.59_1189.77_jgx6a.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/274.0_277.12_4K1Vy.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1297.16_1300.8_38v0Q.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/493.72_495.6_LAH1e.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/60.31_64.13_oNJJh.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/46.0_47.36_Lr6Bt.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/171.72_174.52_2lAQQ.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/198.76_207.0_fFqBj.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/253.48_256.16_qjjSm.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/191.6_193.36_9iuoR.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/836.12_844.0_NSntG.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/712.8_714.24_sQDfC.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/563.05_563.83_5P5Jh.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/718.96_720.16_45yrt.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/662.92_664.95_frNhY.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/587.97_589.16_MQ9U6.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/40.79_45.09_4BpPa.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/243.92_245.12_FASQQ.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/497.43_498.74_bQe1n.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/433.36_434.8_1fhuu.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/804.91_812.13_3OAi2.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/508.8_510.32_YkirA.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/532.2_533.24_ueY5Z.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/561.75_569.09_d1GZt.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1077.72_1084.6_HRTCA.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/242.88_247.4_4WFtO.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/534.36_535.28_3okJ6.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1090.24_1091.2_IK3sV.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/544.92_546.96_ikEj7.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/699.68_701.2_s2bUA.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/774.44_777.24_1Q9mF.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/653.79_660.33_5JP9L.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/572.36_577.0_lskus.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/176.2_178.08_S9RwK.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/619.59_621.03_aXumC.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/335.56_343.28_FUvfy.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/303.32_306.16_uyNqX.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/744.08_746.08_fxxko.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/640.26_644.37_0Sfed.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/520.56_522.96_xpDAA.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/195.55_197.07_foux9.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1146.74_1149.06_bijSr.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/611.12_612.72_pxznt.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/643.22_647.9_wqIG2.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1178.86_1182.42_F3DXM.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/562.24_563.36_NQNO0.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/677.5_680.58_wm2Wp.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/259.72_260.76_2Q46A.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/883.39_890.81_W5nAb.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/692.24_693.36_MuYvX.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/809.72_810.83_9TbhA.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/959.32_962.64_gaYC0.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/149.93_150.78_Ni6pL.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/448.6_451.6_PpjH0.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/597.52_602.2_1qJKM.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/951.52_956.84_vmw4t.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/866.48_868.08_zzZ9e.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/528.35_535.41_tc3VY.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1001.2_1009.4_DcbL1.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/730.0_732.76_UDnvN.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/424.16_427.2_FBzac.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/731.59_736.66_rh4kg.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/296.64_299.64_n5Ib8.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/930.52_934.24_1YQtt.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/740.68_741.76_TNQOv.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/68.35_73.45_Kb51D.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/281.11_288.25_AQq0f.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/553.96_557.96_bC13Z.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/128.38_132.86_BqHSr.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1047.8_1049.68_Ubb1a.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/264.87_267.49_Be1fa.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/542.0_543.92_NTTmB.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/492.72_494.7_CkTgT.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/642.08_643.08_PbV0h.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/646.47_650.74_Ejwrs.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/238.28_240.24_dJLat.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/514.05_515.16_KcmJP.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/964.36_966.08_ZVn2D.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/937.59_943.61_yrPZo.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/324.44_325.68_EF8CH.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/152.84_158.52_R3Kp6.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/660.35_668.09_OiYD4.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/927.2_929.52_aLPSs.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1096.91_1104.61_Ovhc2.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/187.32_189.52_FHrr4.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/571.72_573.88_ZP9nd.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/237.31_243.69_uymnP.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/477.46_490.18_N0gd3.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/82.36_85.72_4SoZS.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/353.7_355.82_0XZXb.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1074.28_1075.2_00PPC.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/531.39_538.05_Ec8b1.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/588.79_595.85_xheD7.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/635.24_637.88_hOeLO.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1113.9_1116.58_2U5Hu.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/297.36_298.36_wxuJv.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/773.92_776.84_HBFdw.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/179.92_181.52_gMjRJ.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/667.6_674.76_iIMdj.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/735.28_736.4_f5TMk.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/810.92_813.03_jjx6L.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1010.42_1015.02_l4Nv2.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/493.2_500.4_NBZ6Y.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/752.63_754.12_hUdNH.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/573.68_577.52_79gMu.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/764.68_771.44_nEDS4.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/766.68_770.04_vtVGr.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/763.47_764.53_ClBJh.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/944.56_950.76_EjwLv.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/646.15_653.77_EhSzY.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/956.55_962.17_7NRoB.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/736.08_742.84_gO35j.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/333.8_335.32_crgA2.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/574.0_576.2_IXuKj.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/637.48_639.16_1gNdu.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1177.88_1184.32_alvzz.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/933.04_940.04_isgoz.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/676.16_680.28_e5XzG.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/639.87_646.13_OJfdS.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/572.36_577.0_lskus.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/424.16_427.2_FBzac.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1206.79_1209.09_To3CQ.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/764.68_771.44_nEDS4.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/138.09_140.95_cAEc6.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/917.91_925.69_U2dal.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/33.52_40.64_SEcuQ.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/555.76_557.36_juNiE.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/468.2_469.56_fslXq.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/712.92_715.88_KSynn.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/397.34_400.16_pC1YI.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/182.26_183.91_PPC5A.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/870.04_877.84_3lSff.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/334.52_339.16_kCzC6.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/400.83_403.85_9Qixz.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/519.05_520.62_ahfmB.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/922.71_930.45_rzpbC.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/337.67_344.09_zlI7V.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1178.39_1186.17_J6Ceo.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/378.76_380.76_VW6lX.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/92.3_94.49_Snhwi.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/322.88_324.6_QQHt8.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/574.92_576.44_VSWJd.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/408.76_410.92_7m9Dc.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1172.91_1179.65_5CWQj.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/729.76_731.88_ALHuZ.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/608.7_611.06_7X8JQ.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/618.76_621.52_2ePja.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1021.43_1028.49_EPhfS.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/272.28_278.76_cQqm5.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/595.87_602.89_R1ZcS.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/593.56_596.08_w7ryg.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/764.44_770.28_b9ZLu.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/781.06_785.54_Sh9ig.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/868.67_875.73_4dcKD.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/296.64_299.64_n5Ib8.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/625.36_627.16_PGjQ5.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/612.67_614.58_l94rd.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/574.55_580.81_jlVMs.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/511.76_515.68_MKOqY.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/115.94_117.98_CAOWe.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/412.36_418.8_3umGf.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/101.12_102.24_vnNfV.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/46.39_48.29_IroEU.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/636.12_639.56_OX1w3.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/783.47_790.33_XxLyO.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/748.24_751.0_8PkLg.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/503.8_509.48_IdNYC.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/695.6_696.92_vDCgH.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/146.12_147.8_SUFFJ.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1274.36_1282.44_00rux.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/786.75_792.77_ji4tE.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/889.6_897.0_iY5Pb.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/751.8_758.84_CaF6N.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/983.7_988.42_riNc8.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/370.16_372.96_YPZ1L.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/555.22_559.66_19MOK.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/563.8_564.53_apqVf.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/580.48_581.28_xGU0x.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/750.8_752.66_YITGw.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/326.84_328.8_Ch0AY.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/420.6_423.24_7daq9.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/75.96_79.08_NgKCE.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/685.96_694.12_FoN6h.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/636.08_637.48_Ci0tD.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/423.52_425.52_xLBmM.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/939.56_942.36_sO1Vh.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/810.92_813.03_jjx6L.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/525.24_530.24_yo3jx.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/143.84_150.24_lyH5B.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/395.0_397.04_MW2me.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/803.63_805.16_OlsdW.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/236.84_239.32_zMxuJ.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/935.88_941.24_XPsE4.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/200.2_205.4_yEWTV.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/825.4_827.44_XC22J.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/303.04_304.4_1c2vL.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/464.12_465.64_WXAfP.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1085.56_1091.76_waxc7.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/431.08_435.28_kR6dd.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/514.07_520.41_BLabp.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/138.76_140.92_P7Xtg.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/747.8_753.48_qw0We.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/116.52_118.76_f926m.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/669.96_671.92_Zm5ye.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/171.88_173.4_PpWaQ.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/589.88_590.84_Tvuz3.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/862.08_864.4_piUtO.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1035.68_1037.12_HygSE.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/474.6_478.64_s8XlT.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/390.04_394.12_q4anc.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/549.11_555.25_kj7yt.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/577.96_582.88_yED56.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/172.88_179.08_j8437.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/573.26_575.58_w4sRl.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/451.84_454.2_Ag4D3.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/415.76_416.92_dFhWM.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/737.88_741.96_2JeA4.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/28.38_30.58_Bv4y7.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/435.68_441.92_aSRhx.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/285.8_287.24_NI9Ga.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/113.72_117.2_6xTlp.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/117.47_121.13_FYvI8.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1167.9_1170.22_YioOk.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/162.02_166.46_A0uLu.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1066.64_1072.96_mLTBN.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/710.74_712.62_B4TBH.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/330.12_333.84_xLghC.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1384.08_1385.0_Pf7zh.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/349.52_352.12_Pg3lR.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/472.48_480.12_XwsWs.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/546.8_548.08_LGVaa.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/668.11_676.09_TkH0P.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/257.92_260.24_wUByf.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/452.76_455.36_AQV7f.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/412.76_414.0_uBYtN.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/256.14_260.7_68arR.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/350.96_353.76_1vzI9.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/567.36_569.44_p1grn.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/459.56_464.12_D7iOT.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/756.54_757.78_IlWwI.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/120.12_124.44_MsX5U.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/230.4_236.72_uF8w2.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/773.55_775.95_BHuqt.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1160.95_1165.37_wB50e.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/394.16_396.4_8gxUq.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/966.4_968.04_qbAxF.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/595.12_597.36_TVOL5.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/507.8_511.04_6ZoHN.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/944.88_946.64_vnXND.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1104.63_1110.53_oKpld.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/640.88_642.2_vv8hb.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/564.28_567.32_I2lfA.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/465.68_466.72_qkx1a.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/404.8_413.12_39dN2.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/408.51_415.45_QZ1T0.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/612.72_615.92_gNkzL.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/215.12_217.84_CdvAT.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/146.18_148.53_iCttC.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1461.68_1464.16_g7INC.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/946.52_950.04_hgaHL.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/545.16_546.72_NKrmF.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1119.27_1126.57_suMQ6.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/530.88_532.04_G0LAs.txt
# ...
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/628.8_635.8_l4JGq.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/690.84_693.96_OHRGE.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/941.4_944.2_HAZXO.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1079.8_1083.72_chVnR.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/147.28_152.64_m1icd.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/611.12_612.72_pxznt.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/893.0_899.2_8ZpjL.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/243.71_251.25_2JSOo.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/755.16_758.68_aEdex.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/103.72_107.16_69HQ7.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/426.44_433.52_8XPfJ.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/138.78_139.9_TkIvM.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/764.52_766.32_VcxSg.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/396.32_400.04_jEKna.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/890.83_897.53_RmFE6.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/602.42_603.58_JGug5.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/412.54_415.94_HJ7D7.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1093.23_1100.85_tkE3m.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/854.64_862.36_P6TNz.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/607.6_614.28_O1sXA.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/447.46_454.78_ttzhl.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/415.47_423.09_KoFJR.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/386.52_387.6_T6QZw.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/517.44_519.0_G2xNW.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/428.96_431.16_AFqc9.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/225.64_227.48_MBLO9.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/921.92_925.28_fqDug.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/538.84_542.6_mmqVj.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/977.32_984.32_RrhEq.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/523.12_528.28_pFBws.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/115.52_117.96_3nzgt.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/208.56_209.8_U5DOO.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/856.92_861.0_OtYl7.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/519.76_521.92_4J57o.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1051.47_1058.49_PdbLJ.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/522.06_523.62_p3rzV.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/272.28_278.76_cQqm5.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/51.23_58.97_Zq4ew.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/272.64_279.76_pjbci.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/427.36_428.92_gxh9R.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/939.98_943.38_OkTxr.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1182.7_1187.14_OBdLQ.opus
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/663.0_664.4_RBfHV.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/696.4_698.04_K3ww3.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1140.87_1148.77_mY3Ma.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/617.0_618.36_eDLH7.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/491.76_493.64_p3689.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/177.24_179.56_0s0sv.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/440.12_443.0_mhhAe.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/602.32_606.08_IWMz9.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/387.99_395.01_ZbDft.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1058.35_1063.05_oLvce.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/820.2_822.04_yRNVd.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/516.96_519.8_76cSD.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/820.76_829.12_DFfWe.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1000.87_1008.45_AthIU.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1326.44_1327.84_pcYOi.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/610.48_612.6_NovfH.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/560.52_567.4_PrYxW.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1478.04_1480.52_9bFqb.opus
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/240.28_243.72_274nj.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/602.91_607.57_3Yv9A.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/695.74_700.34_d9OFP.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1254.07_1260.37_PkiXL.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/461.88_463.64_k7oc7.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/444.76_448.0_qyinF.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/79.4_82.16_rSq3m.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/432.0_438.24_Y0rN6.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1189.28_1190.96_tk8iW.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1241.51_1248.81_DLiqd.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/384.6_387.04_n963G.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/362.08_366.48_zNlH5.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/746.6_748.44_FxkB2.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/399.36_401.2_A4aCb.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/867.76_869.8_0kKd1.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/437.15_444.93_bq7nu.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/638.99_641.61_ztFcd.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/333.12_334.36_cVRjx.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/715.22_719.86_m3749.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/582.68_588.92_J4Tbn.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/492.88_500.32_C2Tl2.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/399.72_402.84_eVVL7.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/367.76_368.76_uED0J.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/518.2_520.72_g4iqG.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/542.0_543.92_NTTmB.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/608.36_610.64_50FzH.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/638.18_642.02_fQ6mt.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/809.72_810.83_9TbhA.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/410.84_413.72_YcLUQ.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/768.48_770.8_ztr5X.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/607.59_614.89_c7wM6.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/469.72_477.12_mr4qk.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/200.32_208.36_5LQhJ.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1379.92_1381.04_fKBzY.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1264.36_1265.68_bXxLI.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1030.27_1036.85_WWvrm.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1072.44_1075.24_GAH53.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/739.76_740.72_aJbRC.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/426.48_429.4_qzeQK.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/956.88_959.44_ywJho.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1195.04_1198.12_TJVgX.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1169.92_1178.24_J9QI9.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/721.35_728.37_RsI5N.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/569.96_571.32_pMBoH.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/818.03_823.17_Il0NT.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/719.04_720.08_0gGkh.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/492.99_499.33_0tOJW.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/674.08_675.4_h0nzr.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/405.08_407.6_bZOSL.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/992.72_999.56_NNfoi.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/689.02_694.66_DE0fn.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/930.47_937.57_2nZCA.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/627.59_632.37_CRISa.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/698.47_706.25_qaxde.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/612.72_616.12_u9hHq.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/485.11_492.33_iaJ5p.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/742.47_743.16_w9Frg.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/646.08_648.56_gPENL.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/885.0_888.24_j9FlA.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/860.31_865.17_IxEyT.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/469.88_472.24_SqSde.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/847.04_849.32_1Z2Wq.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/427.38_429.45_5HAYl.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/294.63_298.17_4FbYV.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/736.51_739.41_0G4QJ.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/818.63_820.53_fFKcL.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/604.28_606.96_GoxVo.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/405.84_407.44_CGbmf.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1041.76_1043.2_n8Ewt.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/865.9_870.58_M7WES.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/390.04_394.12_q4anc.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/256.87_264.85_4AVU8.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/815.92_818.41_vLiA2.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/135.24_136.6_0wIjb.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/943.63_948.93_KOWGx.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/715.4_717.4_YFjdX.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/949.4_952.36_31wIR.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/569.68_577.32_c1yVj.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/47.96_51.68_81zFM.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/960.48_962.12_8zq4J.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/380.44_384.48_Z3qo5.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/366.48_367.4_muTVR.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/361.56_364.72_3kJfH.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/519.05_520.62_ahfmB.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/790.35_797.17_EegSM.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1219.67_1224.05_iw4kv.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/315.56_320.88_RwGtv.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/680.32_682.08_13IwY.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/617.0_618.36_eDLH7.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1171.1_1177.5_BRb63.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/412.96_415.16_FtM1a.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1027.2_1029.16_Yh0Wv.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/661.51_662.91_kHfJ9.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/692.72_697.03_FqhGC.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1149.98_1153.18_qgsJI.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/420.74_422.46_dB9S9.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/660.35_668.09_OiYD4.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/476.84_477.7_o4pIO.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/386.31_391.93_4rWiU.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/506.86_509.26_bz963.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/677.5_680.58_wm2Wp.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/266.02_271.3_D3rJf.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/444.76_448.0_qyinF.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/454.16_455.84_iLWuo.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/276.71_281.61_87mBK.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/205.63_213.61_B9WGh.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/650.76_652.08_FvVU8.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/143.84_150.24_lyH5B.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/378.76_380.76_VW6lX.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/401.28_403.2_eNVfe.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/781.76_786.56_OPsHG.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/624.0_626.0_2LsPs.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1268.08_1274.68_JHhgI.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/722.86_725.54_BfRUA.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/381.52_384.04_VVGot.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/122.03_128.73_22XzG.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/272.44_274.32_KkSmg.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/816.48_818.76_8hGXw.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/533.6_534.96_2si3P.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/303.07_309.77_EGXm1.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/533.76_539.16_e1GP3.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/1013.4_1020.84_0dfCE.wav
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/252.84_254.64_xPUZO.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/787.24_788.56_RmIZd.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/925.44_929.2_42Bix.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/198.03_203.61_llh07.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/498.28_500.28_HQxiE.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/618.08_623.64_WoH8q.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/314.97_317.16_GO80s.txt
# Đã xóa tệp: /app/ZH_datapreprocess/WenetSpeech/Cleaned_data/499.44_500.36_fby0x.wav
# Đã xóa tất cả các tệp trong thư mục thành công.

# %%
# Sử dụng hàm để tạo chuỗi ngẫu nhiên
random_string = generate_random_string()
print(random_string)
# Out:
# JcPsm

# %% [markdown]
# # đếm số file opus trong thư mục

# %%
import os

def find_opus_files(folder_path):
    opus_files = []

    # Duyệt qua tất cả các thư mục và tệp tin trong thư mục chính
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            # Kiểm tra nếu tệp có đuôi là ".opus"
            if file.endswith(".opus"):
                # Tạo đường dẫn đầy đủ và thêm vào danh sách
                file_path = os.path.join(root, file)
                opus_files.append(file_path)

    return opus_files

# Thư mục chính bạn muốn tìm kiếm
main_folder = '/app/WenetSpeech/WenetSpeech/audio'

# Lấy tất cả đường dẫn của các tệp .opus trong thư mục con
opus_file_paths = find_opus_files(main_folder)
# print(len)
# for opus_file_path in opus_file_paths:
#     print(opus_file_path)

a = 'audio/train/youtube/B00000/Y0000000000_--5llN02F84.opus'
def find_element_containing_a(a, str_list):
    for element in str_list:
        if a in element:
            return element
    return None



result = find_element_containing_a(a, opus_file_paths)

if result:
    print(f"Phần tử chứa '{a}': {result}")
else:
    print(f"Không tìm thấy phần tử chứa '{a}' trong danh sách.")
# Out:
# Phần tử chứa 'audio/train/youtube/B00000/Y0000000000_--5llN02F84.opus': /app/WenetSpeech/WenetSpeech/audio/train/youtube/B00000/Y0000000000_--5llN02F84.opus

# %%
import subprocess

def cut_opus_file_ffmpeg(input_path, output_path, start_time, end_time):
    try:
        # Sử dụng FFmpeg để cắt file âm thanh
        subprocess.run([
            'ffmpeg',
            '-i', input_path,
            '-ss', str(start_time),
            '-to', str(end_time),
            '-c', 'copy',
            output_path
        ], check=True)

        print(f"Đã cắt file từ {start_time} giây đến {end_time} giây và lưu thành {output_path}")
    except subprocess.CalledProcessError as e:
        print(f"Có lỗi xảy ra: {e}")

# Thay đổi đường dẫn đến file Opus của bạn và đặt thời gian cắt
input_opus_path = '/app/WenetSpeech/WenetSpeech/audio/dev/third_party/B00000/DEV_T0000000000.opus'
output_opus_path = '/app/WenetSpeech/WenetSpeech/audio/dev/third_party/B00000/aaa.opus'
start_time_to_cut = 10  # Thời điểm bắt đầu cắt (giây)
end_time_to_cut = 20    # Thời điểm kết thúc cắt (giây)

cut_opus_file_ffmpeg(input_opus_path, output_opus_path, start_time_to_cut, end_time_to_cut)
# Out:
# Đã cắt file từ 10 giây đến 20 giây và lưu thành /app/WenetSpeech/WenetSpeech/audio/dev/third_party/B00000/aaa.opus
# ffmpeg version 5.1.4-0+deb12u1 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12 (Debian 12.2.0-14)
#   configuration: --prefix=/usr --extra-version=0+deb12u1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librist --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --disable-sndio --enable-libjxl --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-libplacebo --enable-librav1e --enable-shared
#   libavutil      57. 28.100 / 57. 28.100
#   libavcodec     59. 37.100 / 59. 37.100
#   libavformat    59. 27.100 / 59. 27.100
#   libavdevice    59.  7.100 / 59.  7.100
#   libavfilter     8. 44.100 /  8. 44.100
#   libswscale      6.  7.100 /  6.  7.100
#   libswresample   4.  7.100 /  4.  7.100
#   libpostproc    56.  6.100 / 56.  6.100
# Input #0, ogg, from '/app/WenetSpeech/WenetSpeech/audio/dev/third_party/B00000/DEV_T0000000000.opus':
#   Duration: 00:00:05.61, start: 0.000000, bitrate: 32 kb/s
#   Stream #0:0: Audio: opus, 48000 Hz, mono, fltp
#     Metadata:
#       encoder         : Lavc57.107.100 libopus
# Output #0, opus, to '/app/WenetSpeech/WenetSpeech/audio/dev/third_party/B00000/aaa.opus':
#   Metadata:
#     encoder         : Lavf59.27.100
#   Stream #0:0: Audio: opus, 48000 Hz, mono, fltp
#     Metadata:
#       encoder         : Lavc57.107.100 libopus
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# video:0kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
